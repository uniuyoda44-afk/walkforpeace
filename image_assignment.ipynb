# %%
# display walk.jpg image for inspection
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open(r"c:\Users\Paulinus Kingsley\OneDrive\Apps\Walk for Peace\walk.jpg")
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1079.5), np.float64(719.5), np.float64(-0.5))
